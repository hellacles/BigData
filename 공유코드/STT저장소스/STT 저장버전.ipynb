# %% [markdown]
# # 원본 절대 건들지 말 것!!

# %%
# 원본입니다.
# 박성준 버전 저장하기

import io
import os
import pandas as pd

# 제이슨 파일 불러오기? 이건 뭔지 모르겠다 / 인증키 같다
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="./data/test-heracelus-epf9-088e6dc92eba.json"

# 인식할 인텐트 리스트와 라벨링 리스트
intent_list = ['운행시작', '가게전화', '가게도착', '픽업완료', '영수증번호', '소요시간선택', '배달완료']

# 나중에 csv 파일 저장하기 전 시리즈를 저장할 리스트 생성
text = []
intent_index = []
label = []
labeling = -1 # 요건 라벨 인덱스에 들어갈 값 먼저 정해주기

# 인텐트 폴더이름을 for 문으로 돌리자
for intent in intent_list :
    path= "./data/voice/"
    intent_path = intent
    labeling += 1
    print("여기서부터는" + intent + "폴더입니다.")
    
    # 폴더 내에서 파일을 하나씩 돌리자
    for k in range(15): # 각 폴더 중 최대 파일 갯수로 설정
        
        try :
            # 파일명 지정
            file_path = str(k) + ".wav"

            # 구글 클라우드에서 speech 모듈 깔기
            from google.cloud import speech

            # 객체 생성
            client = speech.SpeechClient()

            # 파일 패쓰 지정
            file_name = os.path.join(os.path.dirname(path), intent_path, file_path)

            # 음성 파일을 열어서 텍스트로??
            with io.open(file_name, "rb") as audio_file:
                content = audio_file.read()
                audio = speech.RecognitionAudio(content=content)
            config = speech.RecognitionConfig(
                encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
                ##음성파일 hertz
                sample_rate_hertz=16000, # 나는 m4a를 wav로 변환하니까 16000되서 이렇게 설정
                language_code="ko-KR",
                audio_channel_count=2 # iphone 쓰는 사람은 이렇게 설정해줘야 함
            )

            
            # 텍스트 감지
            response = client.recognize(config=config, audio=audio)

            for result in response.results:
                print(result.alternatives[0].transcript)
                text_value = result.alternatives[0].transcript


#             from hanspell import spell_checker

#             text = result.alternatives[0].transcript

#             sent = text
#             spelled_sent = spell_checker.check(sent)

#             fixed_sent = spelled_sent.checked
            
            # 리스트에 각 저장
            text.append(text_value)
            intent_index.append(intent)
            label.append(labeling)
            
        except :
            pass

# 데이터프레임으로 변환
df = pd.DataFrame([x for x in zip(text, intent_index, label)])
df.columns = ['text', 'intent', 'label']
display(df)

# 데이터프레임 저장
df.to_csv('./data/text/박성준녹음.xlsx')
# Out:
# 여기서부터는운행시작폴더입니다.
# 은행을 하자
# 운행을 시작해
# 은행 시작해 주세요
# 운행 해
# 은행 하자
# 은행 시작하자
# 운행 시작해
# 배달을 시작해 주세요
# 배달을 시작해
# 배달을 하자
# 대단하다
# 배달해
# 시작하자
# 여기서부터는가게전화폴더입니다.
# 식당에 전화
# 식당에 전화 좀 해 줘
# 식당 전화 좀
# 가게 전화 좀
# 가게 전화
# 가게에 전화 연결해 줘
# 식당에 전화 연결해 줘
# 음식점에 전화해 줘
# 음식점에 전화
# 여기서부터는가게도착폴더입니다.
# 도착
# 도착했습니다
# 음식점 왔어
# 식당 왔어
# 가게 왔어
# 식당 도착했음
# 식당 도착했어
# 가게 도착했음
# 가게 도착했어
# 식당 도착
# 가게 도착
# 여기서부터는픽업완료폴더입니다.
# 여기서부터는영수증번호폴더입니다.
# 여기서부터는소요시간선택폴더입니다.
# 여기서부터는배달완료폴더입니다.
# 메달 완료
#             text intent  label
# 0         은행을 하자   운행시작      0
# 1        운행을 시작해   운행시작      0
# 2     은행 시작해 주세요   운행시작      0
# 3           운행 해   운행시작      0
# 4          은행 하자   운행시작      0
# 5        은행 시작하자   운행시작      0
# 6         운행 시작해   운행시작      0
# 7    배달을 시작해 주세요   운행시작      0
# 8        배달을 시작해   운행시작      0
# 9         배달을 하자   운행시작      0
# 10          대단하다   운행시작      0
# 11           배달해   운행시작      0
# 12          시작하자   운행시작      0
# 13        식당에 전화   가게전화      1
# 14  식당에 전화 좀 해 줘   가게전화      1
# 15       식당 전화 좀   가게전화      1
# 16       가게 전화 좀   가게전화      1
# 17         가게 전화   가게전화      1
# 18  가게에 전화 연결해 줘   가게전화      1
# 19  식당에 전화 연결해 줘   가게전화      1
# 20    음식점에 전화해 줘   가게전화      1
# 21       음식점에 전화   가게전화      1
# 22            도착   가게도착      2
# 23        도착했습니다   가게도착      2
# 24        음식점 왔어   가게도착      2
# 25         식당 왔어   가게도착      2
# 26         가게 왔어   가게도착      2
# 27       식당 도착했음   가게도착      2
# 28       식당 도착했어   가게도착      2
# 29       가게 도착했음   가게도착      2
# 30       가게 도착했어   가게도착      2
# 31         식당 도착   가게도착      2
# 32         가게 도착   가게도착      2
# 33         메달 완료   배달완료      6

# %% [markdown]
# # 재환이 파일로 실행해보자

# %%
# 재환이 버전 저장하기

import io
import os
import pandas as pd

# 제이슨 파일 불러오기? 이건 뭔지 모르겠다
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="./data/test-heracelus-epf9-088e6dc92eba.json"

# 인식할 인텐트 리스트와 라벨링 리스트
intent_list = ['운행시작', '가게전화', '가게도착', '픽업완료', '영수증번호', '소요시간', '배달완료']

# 나중에 csv 파일 저장하기 전 시리즈를 저장할 리스트 생성
text = []
intent_index = []
label = []
labeling = -1 # 요건 라벨 인덱스에 들어갈 값 먼저 정해주기

# 인텐트 폴더이름을 for 문으로 돌리자
for intent in intent_list :
    path= "./data/음성녹음/재환_voice/"
    intent_path = intent
    labeling += 1
    print("여기서부터는 " + intent + " 폴더입니다.")
    
    # 폴더 내에서 파일을 하나씩 돌리자
    for k in range(30):
        
        try :
            # 파일명 지정
            file_path = str(k) + ".wav"

            # 구글 클라우드에서 speech 모듈 깔기
            from google.cloud import speech

            # 객체 생성
            client = speech.SpeechClient()

            # 파일 패쓰 지정
            file_name = os.path.join(os.path.dirname(path), intent_path, file_path)

            # 음성 파일을 열어서 텍스트로??
            with io.open(file_name, "rb") as audio_file:
                content = audio_file.read()
                audio = speech.RecognitionAudio(content=content)
            config = speech.RecognitionConfig(
                encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
                ##음성파일 hertz
                sample_rate_hertz=22050,
                language_code="ko-KR",
                audio_channel_count=2
            )

            
            # 텍스트 감지
            response = client.recognize(config=config, audio=audio)

            for result in response.results:
                print(result.alternatives[0].transcript)
                text_value = result.alternatives[0].transcript
            
            # 리스트에 각 저장
            text.append(text_value)
            intent_index.append(intent)
            label.append(labeling)
            
        except :
            pass
        
df = pd.DataFrame([x for x in zip(text, intent_index, label)])
df.columns = ['text', 'intent', 'label']
display(df)
# Out:
# 여기서부터는운행시작폴더입니다.
# 은행 시작해
# 운행 시작하자
# 운행 하자
# 은행 해
# 은행 시작해 주세요
# 운행을 시작해
# 동생을 시작하자
# 오늘 하자
# 운행을 해
# 배달을 시작해 주세요
# 대답을 시작해
# 배달을 시작하자
# 대답을 하자
# 배달을 해
# 배달을 시작해 주세요
# 배달 시작해
# 배달 시작하자
# 배달하자
# 배달해
# 배달 시작해 주세요
# 여기서부터는가게전화폴더입니다.
# 식당에 전화해 줘
# 식당에 전화하자
# 식당에 전화
# 식당 전화해라
# 식당 전화해 주세요
# 가게에 전화해 줘
# 가게에 전화하자
# 가게에 전화
# 가게 전화해라
# 한테 전화해 주세요
# 음식점에 전화해 줘
# 음식점에 전화하자
# 음식점에 전화
# 음식점 전화해라
# 음식점 전화해 주세요
# 여기서부터는가게도착폴더입니다.
# 식당 도착
# 식당 도착했어
# 식당 도착했음
# 식당 도착했다
# 갔다 왔어
# 식당에 도착
# 식당에 도착했어
# 식당에 도착했음
# 식당에 도착했다
# 식당에 왔어
# 음식점 도착
# 음식점 도착했어
# 음식점 도착했음
# 음식점 도착했다
# 음식점 왔어
# 음식점에 도착
# 음식점에 도착했어
# 음식점에 도착했음
# 음식점에 도착했다
# 음식점에 왔어
# 가게 도착
# 가게 도착했어
# 가게 도착했음
# 가게 도착했다
# 가져왔어
# 가게에 도착
# 가게 도착했어
# 가게에 도착했음
# 가게에 도착했다
# 여기서부터는픽업완료폴더입니다.
# 픽업 했어
# 픽업 완료
# 픽업 완료했어
# 픽업 했고
# 픽업 완료 완료 했고
# 픽업 완료
# 음식 찾았어
# 닫았어
# 찾았고
# 음식 받았고
# 연습 픽업 했고
# 음식 픽업 했어
# 픽업 완료 했고
# 1시 완료
# 여기서부터는영수증번호폴더입니다.
# 영수증 번호 6066
# 영수증 번호 9937
# 구글 영수증 번호 5642
# 영수증 번호 8522
# 영수증 번호 4402
# 영수증 번호 978
# 영수증 번호 7 0 5 6
# 영수증 번호 9385
# 영수증 번호 229
# 영수증 번호 7547
# 주문 번호 9935
# 잘못 주문번호 3931
# 주문 번호 9052
# 해가지고 주문 번호 3715
# 주문 번호 1972
# 5 6 7 7 5
# 그거는 주문 번호 1248
# 4889
# 1달러 5675
# 주문 번호 7613
# 이번 한 번만 더 일자리 4403
# 목소리가 뒷자리 7465
# 자리 7370
# 자리 8 7 6 2
# 10자리 1158
# 뒷자리 8,000
# 뒷자리 9274
# 자리 7868
# 자리 4918
# 여기서부터는소요시간폴더입니다.
# 10분 후 도착
# 10분 있다가 도착
# 20분 후 도착
# 20분 있다 도착
# 30분 후 도착
# 30분 있다가 도착
# 40분 알람
# 40분 있다가 도착
# 여기서부터는배달완료폴더입니다.
# 배달 완료
# 배달 얼른 했어
# 배달 끝냈어
# 나는 끝났어
# 배달 끝
# 음식 배달 완료
# 음식 배달 완료 했어
# 음식 잘 끝냈어
# 음식 잘 끝났어
#             text intent  label
# 0         은행 시작해   운행시작      0
# 1        운행 시작하자   운행시작      0
# 2          운행 하자   운행시작      0
# 3           은행 해   운행시작      0
# 4     은행 시작해 주세요   운행시작      0
# ..           ...    ...    ...
# 119         배달 끝   배달완료      6
# 120     음식 배달 완료   배달완료      6
# 121  음식 배달 완료 했어   배달완료      6
# 122     음식 잘 끝냈어   배달완료      6
# 123     음식 잘 끝났어   배달완료      6
#
# [124 rows x 3 columns]

# %%
df.to_excel('./data/text/재환이녹음.xlsx')
