# %% [markdown]
# # 센서데이터 확인

# %%
import pandas as pd
import numpy as np

# %%
# GEUMCHEON_COW_SMELL_2020.11.09-11.15 

df1 = pd.read_csv('./sensor/GEUMCHEON_COW_SMELL_2020.11.09-11.15.csv', encoding='cp949')
display(df1.head())
# Out:
#   기관 명  송신 서버 번호  데이터 번호   모델명   시리얼                       센싱시간  복합악취센싱값  \
# 0  금천구        14       1  Odor  1007  2020-11-09T00:06:10 09:00      766
# 1  금천구        14       1  Odor  1003  2020-11-09T00:06:43 09:00      417
# 2  금천구        14       1  Odor  1003  2020-11-09T00:16:42 09:00      418
# 3  금천구        14       1  Odor  1007  2020-11-09T00:16:09 09:00      766
# 4  금천구        14       1  Odor  1003  2020-11-09T00:26:41 09:00      419
#
#                   등록일자
# 0  2020-11-09 00:06:28
# 1  2020-11-09 00:09:56
# 2  2020-11-09 00:18:18
# 3  2020-11-09 00:19:02
# 4  2020-11-09 00:26:42

# %%
# GEUMCHEON_SOLITUDE_2020.11.09-11.15

df2 = pd.read_csv('./sensor/GEUMCHEON_COW_SMELL_2020.11.09-11.15.csv', encoding='cp949')
display(df2.head())
# Out:
#   기관 명  송신 서버 번호  데이터 번호   모델명   시리얼                       센싱시간  복합악취센싱값  \
# 0  금천구        14       1  Odor  1007  2020-11-09T00:06:10 09:00      766
# 1  금천구        14       1  Odor  1003  2020-11-09T00:06:43 09:00      417
# 2  금천구        14       1  Odor  1003  2020-11-09T00:16:42 09:00      418
# 3  금천구        14       1  Odor  1007  2020-11-09T00:16:09 09:00      766
# 4  금천구        14       1  Odor  1003  2020-11-09T00:26:41 09:00      419
#
#                   등록일자
# 0  2020-11-09 00:06:28
# 1  2020-11-09 00:09:56
# 2  2020-11-09 00:18:18
# 3  2020-11-09 00:19:02
# 4  2020-11-09 00:26:42

# %%
# SD_STREET_OUT_2020.11.09-11.15

df3 = pd.read_csv('./sensor/SD_STREET_OUT_2020.11.09-11.15.csv', encoding='cp949')
display(df3.head())
# Out:
# Empty DataFrame
# Columns: [기관 명, 송신 서버 번호, 데이터 번호, 모델명, 시리얼, 관측시각, 온도(℃), 습도(%), 미세먼지(㎍/㎥), 초미세먼지(㎍/㎥), 등록일자]
# Index: []

# %%
# TRADITIONAL_MARKET_2020.11.09-11.15

df4 = pd.read_csv('./sensor/TRADITIONAL_MARKET_2020.11.09-11.15.csv', encoding='cp949')
display(df4.head())
# Out:
#   기관 명  송신 서버 번호  데이터 번호     모델 명      기기ID  연기감지 여부(정상:0, 연기감지:1)  \
# 0  서울시        28       1  IC-H100  19910035                      0
# 1  서울시        28       1  IC-H100  19910121                      0
# 2  서울시        28       1  IC-H100  19910092                      0
# 3  서울시        28       1  IC-H100  19910179                      0
# 4  서울시        28       1  IC-H100  19910158                      0
#
#    현재 온도 (°C)  배터리 잔량 (%)         패킷 전송시간                 등록일자
# 0           0           0  20201109000825  2020-11-09 00:08:24
# 1           0           0  20201109000949  2020-11-09 00:09:48
# 2           0           0  20201109001123  2020-11-09 00:11:22
# 3           0           0  20201109002631  2020-11-09 00:26:30
# 4           0           0  20201109003448  2020-11-09 00:34:48

# %%
# YC_SOLITUDE_2020.11.09-11.15 

df5 = pd.read_csv('./sensor/YC_SOLITUDE_2020.11.09-11.15.csv', encoding='cp949')
display(df5.head())
# Out:
#   기관 명  송신 서버 번호  데이터 번호  모델명         시리얼  가동유무  사용전력(W)  빛의밝기(%)  \
# 0  양천구        29       1  340  0a871d4a88     0        2       22
# 1  양천구        29       1  340  b038bbc449     0        0       20
# 2  양천구        29       1  340  a3b7d97490     1       32       20
# 3  양천구        29       1  340  29804faefc     1        0       20
# 4  양천구        29       1  340  05d372d937     1       16       20
#
#    전원상태(꺼짐:0, 켜짐 :1)                 등록일자
# 0                  1  2020-11-09 00:00:12
# 1                  1  2020-11-09 00:00:18
# 2                  1  2020-11-09 00:00:19
# 3                  1  2020-11-09 00:00:26
# 4                  1  2020-11-09 00:00:27

# %%
# Out:
# C:\Users\parkgun\anaconda3\envs\pydatavenv\lib\site-packages\matplotlib\mpl-data\matplotlibrc
