# %%
# 참조 사이트
# https://needjarvis.tistory.com/59
# https://lemontia.tistory.com/903

# 각 용어들에 대해 조금 알아두면 좋을 듯 하다.

# - support(지지도)
# 전체 거래에서 특정 물품 A와 B가 동시에 거래되는 비중
# 해당 규칙이 얼마나 의미있는지 보여줌.
# 지지도 = P(A∩B)
# :A와 B가 동시에 일어난 횟수 / 전체 거래 횟수


# - confiddence(신뢰도)
# A를 포함하는 거래 중 A와 B가 동시에 거래되는 비중
# 신뢰도 = P(A∩B) / P(A)
# :A와 B가 동시에 일어난 횟수 / A가 일어난 횟수

 
# - lift(향상도)
# A라는 상품에서 신뢰도가 동일한 상품 B와 C가 존재할 때, 어떤 상품을 더 추천해야 좋을지 판단.
# A와 B가 동시에 거래된 비중을 A와 B가 서로 독립된 사건일 때 동시에 거래된 비중으로 나눈 값
# 향상도 = P(A∩B) / P(A)*P(B) = P (B|A) / P (B)
# : A와 B가 동시에 일어난 횟수 / A, B가 독립된 사건일 때 A,B가 동시에 일어날 확률

# %%
# apriori에 필요한 모듈 설치 -> pandas와 mlxtend 미리 설치해야 함
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# 연관분석할 데이터셋
# df = pd.read_excel('./data/apriori/뉴스_배달 안전_단어.xlsx')

dataset = [['스파이더', '크래프트', '다날', '배달', '대행', '시장', '결제', '서비스', '혁신', '매일경제'],['연말', '수기', '단계', '격상', '배달', '시장', '매일경제'],['세종시', '배달', '운영', '업무', '협약', '체결', '매일경제'],['네이버', '배달', '대행', '생각', '대로', '투자', '추진'],['배달', '네이버', '배달', '대행', '업체', '중앙', '일보'],['라이더', '수수료', '배달', '주문', '반값', '서울', '경제'],['네이버', '모빌리티', '배달', '사업'],['네이버', '배달', '대행', '생각', '대로', '억원', '투자'],['배달', '근로자', '실태', '현장', '목소리', '배달', '대행', '선점', '업체', '횡포'],['신한은행', '배달', '대행', '라이더', '금융', '서비스', '개발'],['신한은행', '배달', '대행', '라이더', '특화', '금융', '서비스', '제공'],['신한은행', '배달', '대행', '라이더', '특화', '금융', '서비스', '제공', '전용', '체크'],['기사', '배달', '대행', '알바', '배민', '라이더', '시작', '게임', '배달'],['오늘', '커피숍', '취식', '불가', '커피', '업계', '배달', '시장', '긴장'],['라이더', '유니온', '배달', '대행', '사업', '등록', '제화', '약속', '환영'],['해마', '푸드', '맘스', '터치', '배달', '전문', '매장', '론칭', '도약', '발판'],['네이버', '배달', '대행', '생각', '투자'],['초소', '전기차', '이브', '냉온', '모델', '공개', '배달', '시장', '공략'],['계약서', '배달', '대행', '업체'],['스타벅스', '배달', '서비스', '시범', '운영'],['네이버', '배달', '대행', '생각', '투자'],['세종시', '신규', '배달', '대행', '플랫폼', '보이', '마케팅', '지원', '서비스', '개시'],['네이버', '배달', '대행', '생각', '대로', '투자', '추진'],['쓰레기통', '생각', '감정노동', '굴레'],['이낙연', '배달', '대행', '업체', '방문', '라이더', '노동', '실태', '점검'],['바나', '프레', '배달', '대행', '계약', '체결'],['이슈', '네이버', '배달', '대행', '생각', '투자'],['별다방', '커피', '스타벅스', '배달', '서비스'],['하루', '근무', '배달', '노동자',
'],['자토', '바이', '배달', '생태계', '꼼수', '급증', '매일경제'],['창고', '편의점', '마트', '배송', '전쟁'],['사이트', '김용식', '슈퍼히어로', '대표', '로봇', '주행', '배달', '시대', '성큼', '배달', '대행', '종사', '권리'],['배달', '대행', '물류', '사업', '쾌속', '주올', '매출', '목표'],['일본', '택시', '음식', '배달', '전면', '허용', '우버', '경쟁'],['영업', '리포트', '배달', '주문', '폭증', '수수료', '부담'],['컵밥', '배달'],['김윤섭', '유통', '브리핑', '제일제당', '대상', '억원', '규모', '특허'],['배달', '배달', '대행', '업체', '동생', '협박'],['배달', '성희롱', '민원', '배달', '고용', '교육', '문제', '도마'],['코로나', '마스크', '대화', '송파', '배달', '대행', '기사', '확진'],['배민', '허위', '리뷰', '사전', '차단', '시스템', '운영'],['배달', '대행', '업체', '음식점', '주인', '배달', '직접', '이유'],['폭증', '배달', '수요', '오른', '배달', '오토바이', '보험료', '서울', '경제']]

# %%
# 데이터셋을 원핫인코딩처럼 트랜스포밍해주기!
te = TransactionEncoder()
te_result = te.fit(dataset).transform(dataset)

# %%
# 트랜스포밍된 결과를 데이터프레임으로 형성
# 컬럼명이 키워드 / 각 row마다 포함된 키워드에 True를 반환
df = pd.DataFrame(te_result, columns=te.columns_)
display(df)
# Out:
#        가려진     가방     가열     가유     가입     가짜     가치   간장게장     갈등     갈릭  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 180  False  False  False  False  False  False  False  False  False  False
# 181  False  False  False  False  False  False  False  False  False  False
# 182  False  False  False  False  False  False  False  False  False  False
# 183  False  False  False  False  False  False  False  False  False  False
# 184  False  False  False  False  False  False  False  False  False  False
#
#      ...     혼란     확대     확보     확진     환영     활동    활성화     활용     횡포     휴먼
# ...

# %%
# apriori 알고리즘 사용 / 옵션을 주지 않으면 자동으로 지지도 0.5
keywordset = apriori(df, use_colnames=True)
keywordset
# Out:
#     support itemsets
# 0  0.502703     (대행)
# 1  0.859459     (배달)

# %%
# 지지도를 0.1로 낮춰서 apriori 실행
keywordset = apriori(df, min_support=0.1, use_colnames=True)
keywordset
# Out:
#      support      itemsets
# 0   0.502703          (대행)
# 1   0.145946         (라이더)
# 2   0.859459          (배달)
# 3   0.108108          (생각)
# 4   0.113514          (업체)
# 5   0.497297      (배달, 대행)
# 6   0.102703      (업체, 대행)
# 7   0.135135     (배달, 라이더)
# 8   0.102703      (배달, 생각)
# 9   0.113514      (배달, 업체)
# 10  0.102703  (배달, 업체, 대행)

# %%
# 신뢰도 추가 / 기본값은 0.8 / 낮게 설정해야 목록이 나옴 / 0.1로 설정
association_rules(keywordset, metric="confidence", min_threshold=0.1).head(10)
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0        (배달)        (대행)            0.859459            0.502703  0.497297
# 1        (대행)        (배달)            0.502703            0.859459  0.497297
# 2        (업체)        (대행)            0.113514            0.502703  0.102703
# 3        (대행)        (업체)            0.502703            0.113514  0.102703
# 4        (배달)       (라이더)            0.859459            0.145946  0.135135
# 5       (라이더)        (배달)            0.145946            0.859459  0.135135
# 6        (배달)        (생각)            0.859459            0.108108  0.102703
# 7        (생각)        (배달)            0.108108            0.859459  0.102703
# 8        (배달)        (업체)            0.859459            0.113514  0.113514
# 9        (업체)        (배달)            0.113514            0.859459  0.113514
#
#    confidence      lift  leverage  conviction
# 0    0.578616  1.151011  0.065245    1.180153
# ...

# %% [markdown]
# # '배달 안전' 이라는 키워드 연관분석

# %%
# apriori에 필요한 모듈 설치 -> pandas와 mlxtend 미리 설치해야 함
import pandas as pd
import re
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# 연관분석할 데이터셋
df = pd.read_excel('./data/apriori/키워드_배달 안전.xlsx')


# 리스트형식으로 바꾸기
# dataset = df['명사'].tolist()
# print(dataset)

dataset = [['배달', '오토바이', '사고', '기관', '소식', '정책'],['코로나', '집콕', '배달', '주문', '폭증', '라이더', '안전', '장치', '마련', '호소'],['오토바이', '배달', '안전', '교통', '안전', '캠페인'],['전화', '요요기', '안전', '배달', '기능', '추가', '연합뉴스'],['만난', '배달', '대행', '업체', '라이더', '안전', '노컷뉴스'],['우후죽순', '배달', '대행', '안전', '사각', '지대', '배달', '목숨'],['이륜차', '교통', '안전교육', '배달', '이륜차', '안전', '운행', '약속'],['라이더', '배달', '경남', '이륜차', '교통', '안전', '한경닷컴'],['사고', '다발', '지역', '접근', '배달', '알람', '이륜차', '안전', '관리', '강화'],['요기', '안전', '배달', '캠페인', '요기', '사장', '사이트'],['오토바이', '배달', '작업', '안전', '안전', '보건', '공단'],['화장실', '독촉', '배달', '기사', '안전', '배달', '필요'],['라이더', '안전', '국회', '배달', '기사'],['쿠팡', '배달', '파트너', '안전교육', '수료', '만원', '특템'],['배달', '위해', '라이더', '안전보장', '필요', '참여', '혁신'],['통한', '배달', '방법', '배달', '기본', '사항'],['배달', '민족', '서울시', '안전', '배달', '문화', '코리아'],['배달', '죽음', '라이더', '사고', '건위'],['배달', '오토바이', '사고', '정부', '업계', '머리', '정책', '뉴스'],['배민아', '데미', '민트', '라이더', '시즌', '안전', '배달', '실천'],['교통', '안전', '배달', '민족', '이륜차', '교통사고', '예방', '업무', '협약', '체결'],['전화', '요요기', '안전', '배달', '기능', '추가', '매일'],['전유성', '경찰서', '배달', '업체', '사업', '주종', '사자', '대상', '교통', '안전교육'],['안전', '도시', '경제', '지역', '경제', '남구', '배달'],['유성', '배달', '대행', '업체', '이륜차', '교통', '안전', '운전', '홍보', '뉴스', '뉴스'],['전국', '배달', '라이더', '협회', '배달', '라이더', '교통', '안전교육'],['감염', '과로', '노출', '택배', '배달', '종사', '안전', '뉴스', '토마토'],['배달', '이륜차', '사고', '세종시', '사례', '교통신문'],['속도', '안전', '딜레마', '배달', '라이더', '시흥', '타임즈'],['배달', '부탁', '에너지', '일리'],['수익', '배달', '노동자', '배달', '노동자', '오늘', '사고', '위험'],['배달', '민족', '지방', '경찰청', '라이더', '안전교육', '실시'],['스펙트럼', '배달', '노동자', '안전', '대책', '마련', '인천', '일보'],['이륜차', '배달', '대행', '업체', '방문', '안전교육', '실시', '양산', '타임스'],['배달', '민족', '안전', '운전', '캠페인', '민트', '라이더', '진행', '세이프'],['배달', '민족', '안전', '운전', '캠페인', '민트', '라이더', '진행', '스퀘어'],['안전', '비도', '오토바이', '배달', '사고', '급증', '뉴스'],['요기', '플러스', '라이더', '안전', '배달', '위해', '무더위', '예방', '용품', '지원'],['배달', '일자리', '안전', '사각', '지대', '여전', '연합뉴스'],['배달', '이륜자동차', '교통', '안전', '개선', '방향', '한국', '교통', '연구원'],['기고', '배달', '오토바이', '교통법규', '위반', '사각', '지대'],['배달', '민족', '안전', '운전', '캠페인', '민트', '라이더', '실시'],['배달', '오토바이', '사고', '증가', '꾸리', '중개업', '책임', '강화'],['배달', '민족', '서울시', '배달', '문화', '정착', '협력', '디지털', '투데이'],['배달', '오토바이', '사고', '사망자', '급증', '경찰', '집중', '단속', '선포', '모터'],['사회', '코로나', '배달', '이륜차', '사고', '급증', '안전', '관리', '강화'],['건강', '감염병', '유행', '시기', '외식', '배달', '음식', '수령', '유의사항'],['기고', '배달', '안전', '운행', '매일일보'],['노동', '상담', '산업', '안전', '보건', '이륜자동차', '배달', '종사', '자도', '광주', '드림'],['이륜차', '배달', '대행', '업체', '방문', '안전교육', '실시', '웅상', '뉴스', '웅상', '신문'],['배달', '근로자', '안전', '시스템', '보도자료', '웹드', '로우'],['요기', '배달', '문화', '앞장', '안전', '배달', '캠페인', '실시', '테크', '월드'],['이륜차', '배달', '사고', '심각', '전파', '안전', '신문'],['배민', '라이더', '배달', '민족', '배달', '안전교육'],['배달', '사고', '뉴스'],['주택', '관리사', '협회', '전시회', '안전', '공동', '주택', '배달'],['배달', '민족', '이륜차', '사고', '예방', '교육', '민트', '라이더', '진행', '팍스'],['배달', '음식', '프로그램', '전체', '국민', '방송'],['가열', '배달', '속도', '라이더', '안전'],['안전', '보건', '공단', '캠페인', '신문'],['배달', '차별', '무료', '통화', '결제', '여성', '안전', '서비스'],['태풍', '배달', '중단', '배달', '안전', '먼저', '뉴스'],['배달', '배달', '최고', '안전'],['칼럼', '배달', '배달', '생활화', '안전', '세계'],['요기', '비대', '안전', '배달', '주문', '기능', '제공', '뉴데일리'],['배달', '민족', '라이더', '안전', '배달', '보장', '촉구', '오마이', '뉴스'],['봄철', '이륜차', '배달', '증가', '교통', '안전', '세명', '일보'],['투고', '올해', '이륜차', '배달', '종사', '안전', '관리', '의무', '강원', '신문'],['스타트업', '배달', '대행', '이륜차', '안전', '보호', '착용', '캠페인'],['가이드북', '이륜차', '안전', '배달', '포켓', '안전', '자료', '안전'],['서울', '신문', '단속', '정부', '배달', '오토바이', '안전'],['배달', '기사', '안전', '대책', '배달'],['식약처', '배달', '음식', '안전', '강화', '식품', '음료', '신문'],['남대문', '이륜차', '배달', '안전', '사고', '예방', '스마트', '서울', '경찰'],['요기', '배달', '안전', '배달', '캠페인', '실시', '부산', '일보'],['지상', '배달', '로봇', '도난', '로봇', '신문사'],['패스트푸드', '업계', '배달', '직원', '안전', '강화', '식품', '외식', '경제'],['소비자원', '배달', '판매', '식품', '알레르기', '유발', '성분', '표시'],['기고', '배달', '교통사고', '예방', '지름길', '사이드'],['카드', '배달', '사고', '알고리즘', '방해', '휴먼', '이드'],['한국', '소비자원', '배달', '입점', '프랜차이즈', '알레르기', '성분', '표시'],['드론', '관련', '규제', '개정', '싱가포르', '보안', '뉴스'],['배달', '민족', '위생', '인증', '가게', '뱃지', '논란', '인증', '기관', '세스코'],['거리', '두기', '격상', '배달', '전쟁', '점화', '라이더', '확보', '고객', '유치', '총력전'],['도미노피자', '페이', '코인', '결제', '피자', '배달', '할인', '파이낸셜뉴스'],['안전', '보건', '공단', '인포그래픽', '이륜차', '재해'],['배달', '판매', '포장', '식품', '알레르기', '유발', '성분', '표시', '미흡'],['한국', '소비자원', '배달', '판매', '포장', '식품', '알레르기', '유발'],['배달', '판매', '포장', '식품', '알레르기', '성분', '표시', '미흡', '뉴스'],['벌써', '사망', '음식', '배달', '근무'],['안전', '문화', '지역', '경제', '광명시', '집회', '금지', '행정'],['배달', '입점', '프랜차이즈', '알레르기', '성분', '표시', '미흡', '소셜'],['미디어', '뉴스', '모바일', '사이트', '자원', '배달', '판매', '포장'],['삼성', '화재', '재물', '보험', '상품', '비즈', '안전', '파트너', '출시', '통일', '경제'],['코로나바이러스', '감염증', '뉴스', '이슈', '보도자료', '내용', '보기'],['배달', '프랜차이즈', '알레르기', '성분', '표시', '주의보', '소비자'],['쿠팡', '플렉스', '배민', '커넥트', '보험', '자가용', '배달'],['배달', '입점', '프랜차이즈', '알레르기', '성분', '표시', '미흡', '서울'],['배달', '판매', '포장', '식품', '알레르기', '유발', '성분', '표시', '미흡'],['여수시', '소상', '공인', '지역', '경제', '배달', '내년', '출시'],['코로나', '중앙', '재난', '안전', '대책', '본부', '브리핑'],['과천시', '교통', '안전', '강화', '위해', '스마트', '무인', '단속', '카메라', '설치'],['구리시', '사회', '거리', '두기', '단계', '강화', '뉴스'],['브랜드', '선택', '창업', '성공', '핵심', '끼니', '본사', '경쟁력'],['재난사', '뉴스', '조회', '소방', '뉴스', '소방', '소식', '소방청'],['구미시', '농업', '기술', '센터', '농업', '굴삭기', '안전', '사용', '교육', '실시'],['의왕시', '시민', '생활', '안전', '자전거', '도로명', '부여'],['배달', '민족', '형제', '컴북스', '기업', '총서'],['산업', '안전', '보건', '해설', '원리', '이해', '현장', '적용', '해설'],['배달', '입점', '프랜차이즈', '알레르기', '유발', '성분', '표시', '미흡']]


# 데이터셋을 원핫인코딩처럼 트랜스포밍해주기!
te = TransactionEncoder()
te_result = te.fit(dataset).transform(dataset)


# 트랜스포밍된 결과를 데이터프레임으로 형성
# 컬럼명이 키워드 / 각 row마다 포함된 키워드에 True를 반환
df = pd.DataFrame(te_result, columns=te.columns_)


# apriori 알고리즘 사용 / 옵션을 주지 않으면 자동으로 지지도 0.5
keywordset = apriori(df, use_colnames=True)
display(keywordset)


# 지지도를 0.1로 낮춰서 apriori 실행
keywordset = apriori(df, min_support=0.1, use_colnames=True)
display(keywordset)

# 신뢰도 추가 / 기본값은 0.8 / 낮게 설정해야 목록이 나옴 / 0.1로 설정
association_rules(keywordset, metric="confidence", min_threshold=0.1).head(10)

# support = A와 B가 동시에 일어난 확률 / 전체 횟수
# confidence = A와 B가 동시에 일어난 확률 / A가 일어난 횟수
# lift = A와 B가 동시에 일어난 확률 / A와 B가 독립일 확률
# Out:
#     support itemsets
# 0  0.872727     (배달)
# 1  0.554545     (안전)
#      support       itemsets
# 0   0.127273           (뉴스)
# 1   0.172727          (라이더)
# 2   0.109091           (민족)
# 3   0.872727           (배달)
# 4   0.136364           (사고)
# 5   0.554545           (안전)
# 6   0.154545          (이륜차)
# 7   0.172727      (배달, 라이더)
# 8   0.109091      (라이더, 안전)
# 9   0.109091       (배달, 민족)
# 10  0.136364       (배달, 사고)
# 11  0.472727       (배달, 안전)
# 12  0.145455      (배달, 이륜차)
# 13  0.118182      (안전, 이륜차)
# 14  0.109091  (배달, 라이더, 안전)
# 15  0.109091  (배달, 안전, 이륜차)
#   antecedents consequents  antecedent support  consequent support   support  \
# 0        (배달)       (라이더)            0.872727            0.172727  0.172727
# 1       (라이더)        (배달)            0.172727            0.872727  0.172727
# 2       (라이더)        (안전)            0.172727            0.554545  0.109091
# 3        (안전)       (라이더)            0.554545            0.172727  0.109091
# ...

# %% [markdown]
# # 라이더 라는 키워드 연관분석

# %%
# apriori에 필요한 모듈 설치 -> pandas와 mlxtend 미리 설치해야 함
import pandas as pd
import re
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# 연관분석할 데이터셋
df = pd.read_excel('./data/apriori/키워드_라이더.xlsx')

# 리스트형식으로 바꾸기
dataset = df['명사'].apply(lambda x : eval(x).tolist())

# 데이터셋을 원핫인코딩처럼 트랜스포밍해주기!
te = TransactionEncoder()
te_result = te.fit(dataset).transform(dataset)


# 트랜스포밍된 결과를 데이터프레임으로 형성
# 컬럼명이 키워드 / 각 row마다 포함된 키워드에 True를 반환
df = pd.DataFrame(te_result, columns=te.columns_)


# apriori 알고리즘 사용 / 옵션을 주지 않으면 자동으로 지지도 0.5
keywordset = apriori(df, use_colnames=True)
display(keywordset)


# 지지도를 0.1로 낮춰서 apriori 실행
keywordset = apriori(df, min_support=0.1, use_colnames=True)
display(keywordset)

# 신뢰도 추가 / 기본값은 0.8 / 낮게 설정해야 목록이 나옴 / 0.1로 설정
association_rules(keywordset, metric="confidence", min_threshold=0.1).head(10)

# support = A와 B가 동시에 일어난 확률 / 전체 횟수
# confidence = A와 B가 동시에 일어난 확률 / A가 일어난 횟수
# lift = A와 B가 동시에 일어난 확률 / A와 B가 독립일 확률
# Out:
#     support itemsets
# 0  0.872727     (배달)
# 1  0.554545     (안전)
#      support       itemsets
# 0   0.127273           (뉴스)
# 1   0.172727          (라이더)
# 2   0.109091           (민족)
# 3   0.872727           (배달)
# 4   0.136364           (사고)
# 5   0.554545           (안전)
# 6   0.154545          (이륜차)
# 7   0.172727      (배달, 라이더)
# 8   0.109091      (라이더, 안전)
# 9   0.109091       (배달, 민족)
# 10  0.136364       (사고, 배달)
# 11  0.472727       (배달, 안전)
# 12  0.145455      (배달, 이륜차)
# 13  0.118182      (안전, 이륜차)
# 14  0.109091  (배달, 라이더, 안전)
# 15  0.109091  (배달, 안전, 이륜차)
#   antecedents consequents  antecedent support  consequent support   support  \
# 0        (배달)       (라이더)            0.872727            0.172727  0.172727
# 1       (라이더)        (배달)            0.172727            0.872727  0.172727
# 2       (라이더)        (안전)            0.172727            0.554545  0.109091
# 3        (안전)       (라이더)            0.554545            0.172727  0.109091
# ...
